# %%
import numpy as np

import scipy as sp

# %%
sp.__version__
# Out:
# '1.1.0'

# %%
# 读写wav无损音频文件
from scipy.io import wavfile

# %% [markdown]
# scipy.fftpack模块用来计算快速傅里叶变换
# 速度比传统傅里叶变换更快，是对之前算法的改进
# 图片是二维数据，注意使用fftpack的二维转变方法

# %%
# ifft2 inverse 反转
from scipy.fftpack import fft2,ifft2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
moon.shape
# Out:
# (474, 630)

# %%
moon = plt.imread('./moonlanding.png')
plt.figure(figsize=(12,9))
plt.imshow(moon,cmap = plt.cm.gray)

# %%
moon_fft = fft2(moon)
moon_fft
# Out:
# D:\anacondna\lib\site-packages\scipy\fftpack\basic.py:160: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   z[index] = x
# array([[126598.45      +0.j       ,  -4608.5796 -1892.4688j   ,
#           -322.093    -20.27744j  , ...,   -906.1585 +1539.3081j   ,
#           -322.093    +20.27744j  ,  -4608.5796 +1892.4688j   ],
#        [ -9421.1    +5242.1133j   ,   5224.016  -3171.7434j   ,
#           1607.9927 +1269.4243j   , ...,   -677.34503 -936.16174j  ,
#            354.6247 -1003.8348j   ,   1965.366  -2188.0593j   ],
#        [ -2928.3513 +7280.916j    ,  -1116.4065 +1338.3179j   ,
#           -474.20056 +385.40216j  , ...,    239.7723  -977.2129j   ,
#           1582.9283  -261.95346j  ,   2641.927   -292.09366j  ],
#        ...,
#        [  1850.5718 -2451.1787j   ,   -781.0807   +13.744501j ,
#            377.90707  +12.6699295j, ...,  -1526.7869 +1271.2621j   ,
#          -2705.5718 -3488.529j    ,   1897.404  -2281.9092j   ],
#        [ -2928.3513 -7280.916j    ,   2641.927   +292.09366j  ,
#           1582.9283  +261.95346j  , ...,  -2208.4302   +81.807434j ,
#           -474.20056 -385.40216j  ,  -1116.4065 -1338.3179j   ],
#        [ -9421.1    -5242.1133j   ,   1965.366  +2188.0593j   ,
#            354.6247 +1003.8348j   , ...,   1190.5856 -1431.9937j   ,
#           1607.9927 -1269.4243j   ,   5224.016  +3171.7434j   ]],
#       dtype=complex64)

# %%
np.abs(moon_fft).mean()
# Out:
# 51.193375

# %%
cond = np.abs(moon_fft)>500
cond
# Out:
# array([[ True,  True, False, ...,  True, False,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        ...,
#        [ True,  True, False, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True]])

# %%
moon_fft[cond] = 0

# %%
moon_fft
# Out:
# array([[   0.      +0.j       ,    0.      +0.j       ,
#         -322.093  -20.27744j  , ...,    0.      +0.j       ,
#         -322.093  +20.27744j  ,    0.      +0.j       ],
#        [   0.      +0.j       ,    0.      +0.j       ,
#            0.      +0.j       , ...,    0.      +0.j       ,
#            0.      +0.j       ,    0.      +0.j       ],
#        [   0.      +0.j       ,    0.      +0.j       ,
#            0.      +0.j       , ...,    0.      +0.j       ,
#            0.      +0.j       ,    0.      +0.j       ],
#        ...,
#        [   0.      +0.j       ,    0.      +0.j       ,
#          377.90707+12.6699295j, ...,    0.      +0.j       ,
#            0.      +0.j       ,    0.      +0.j       ],
#        [   0.      +0.j       ,    0.      +0.j       ,
#            0.      +0.j       , ...,    0.      +0.j       ,
#            0.      +0.j       ,    0.      +0.j       ],
#        [   0.      +0.j       ,    0.      +0.j       ,
#            0.      +0.j       , ...,    0.      +0.j       ,
#            0.      +0.j       ,    0.      +0.j       ]], dtype=complex64)

# %%
moon_result = ifft2(moon_fft)
moon_result
# Out:
# D:\anacondna\lib\site-packages\scipy\fftpack\basic.py:160: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   z[index] = x
# array([[-0.2158841 -2.1086850e-18j,  0.08547963-4.8682289e-17j,
#         -0.17341562+1.2980935e-17j, ...,  0.00313992-7.3380489e-17j,
#         -0.1262884 +2.1906762e-17j, -0.12006474-2.9579767e-17j],
#        [-0.07464715-5.9313739e-18j,  0.02630262-2.6135415e-17j,
#         -0.05795981+1.3932330e-17j, ..., -0.10645279+2.1719028e-17j,
#         -0.10607974+4.7120357e-17j, -0.06213436+1.2492355e-17j],
#        [ 0.01300102+6.5576129e-18j, -0.04392404+3.0703507e-18j,
#         -0.03069701-8.9022178e-18j, ..., -0.09355526+5.3146563e-17j,
#         -0.09281505-6.2671136e-18j,  0.0542773 -1.0039507e-16j],
#        ...,
#        [ 0.00554965-1.8008872e-17j, -0.06839301-2.4120074e-17j,
#         -0.11348293+2.8349035e-17j, ...,  0.05521014-1.6788135e-17j,
#         -0.02254207+5.7200989e-17j,  0.17004317-1.9203628e-16j],
#        [-0.0236596 +2.0952098e-17j, -0.21761242+6.2705591e-17j,
#         -0.04112267+2.8428269e-17j, ..., -0.03240317+2.6833532e-17j,
#         -0.03881308+4.1344251e-17j,  0.18942517-1.5533982e-16j],
#        [-0.06233123+6.3520171e-18j,  0.06238206-9.5342732e-18j,
#         -0.05904231+9.1773158e-18j, ..., -0.05108529+7.8768029e-17j,
#         -0.01733968+7.0396981e-17j, -0.04830741+4.1530237e-17j]],
#       dtype=complex64)

# %%
moon2 = np.real(moon_result)
moon2.shape
# Out:
# (474, 630)

# %%
moon3 = np.abs(moon2)
# Out:
# array([[-0.2158841 ,  0.08547963, -0.17341562, ...,  0.00313992,
#         -0.1262884 , -0.12006474],
#        [-0.07464715,  0.02630262, -0.05795981, ..., -0.10645279,
#         -0.10607974, -0.06213436],
#        [ 0.01300102, -0.04392404, -0.03069701, ..., -0.09355526,
#         -0.09281505,  0.0542773 ],
#        ...,
#        [ 0.00554965, -0.06839301, -0.11348293, ...,  0.05521014,
#         -0.02254207,  0.17004317],
#        [-0.0236596 , -0.21761242, -0.04112267, ..., -0.03240317,
#         -0.03881308,  0.18942517],
#        [-0.06233123,  0.06238206, -0.05904231, ..., -0.05108529,
#         -0.01733968, -0.04830741]], dtype=float32)

# %%
plt.figure(figsize=(12,9))

plt.imshow(moon2,cmap = plt.cm.gray)

# %%
# X**2 + Y**2 = 1
# Y = (1 - X**2)**0.5
c = lambda x : (1-x**2)**0.5
x = np.linspace(-1,1,100)
y = c(x)
plt.figure(figsize=(5,5))
plt.plot(x,y)
plt.plot(x,-y)

# %%
s = pi*r**2

pi = s/(r**2)

# r = 1

pi = s

# 半圆

# %%
from scipy import integrate

# %%
# 半圆面积，圆周率一半
integrate.quad(c,-1,1)
# Out:
# (1.5707963267948986, 1.0002356720661965e-09)

# %%
1.5707963267948986*2
# Out:
# 3.141592653589797

# %%
from scipy import io

# %%
moon2
# Out:
# array([[-0.2158841 ,  0.08547963, -0.17341562, ...,  0.00313992,
#         -0.1262884 , -0.12006474],
#        [-0.07464715,  0.02630262, -0.05795981, ..., -0.10645279,
#         -0.10607974, -0.06213436],
#        [ 0.01300102, -0.04392404, -0.03069701, ..., -0.09355526,
#         -0.09281505,  0.0542773 ],
#        ...,
#        [ 0.00554965, -0.06839301, -0.11348293, ...,  0.05521014,
#         -0.02254207,  0.17004317],
#        [-0.0236596 , -0.21761242, -0.04112267, ..., -0.03240317,
#         -0.03881308,  0.18942517],
#        [-0.06233123,  0.06238206, -0.05904231, ..., -0.05108529,
#         -0.01733968, -0.04830741]], dtype=float32)

# %%
io.savemat('moon.mat',mdict={'moon':moon2})

# %%
io.loadmat('./moon.mat')
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file Platform: nt, Created on: Wed Feb 19 16:16:27 2020',
#  '__version__': '1.0',
#  '__globals__': [],
#  'moon': array([[-0.2158841 ,  0.08547963, -0.17341562, ...,  0.00313992,
#          -0.1262884 , -0.12006474],
#         [-0.07464715,  0.02630262, -0.05795981, ..., -0.10645279,
#          -0.10607974, -0.06213436],
#         [ 0.01300102, -0.04392404, -0.03069701, ..., -0.09355526,
#          -0.09281505,  0.0542773 ],
#         ...,
#         [ 0.00554965, -0.06839301, -0.11348293, ...,  0.05521014,
#          -0.02254207,  0.17004317],
#         [-0.0236596 , -0.21761242, -0.04112267, ..., -0.03240317,
#          -0.03881308,  0.18942517],
#         [-0.06233123,  0.06238206, -0.05904231, ..., -0.05108529,
#          -0.01733968, -0.04830741]], dtype=float32)}

# %%
from scipy import misc

# %%
cat = misc.imread('./cat.jpg')
cat
# Out:
# D:\anacondna\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
# array([[[231, 186, 131],
#         [232, 187, 132],
#         [233, 188, 133],
#         ...,
#         [100,  54,  54],
#         [ 92,  48,  47],
#         [ 85,  43,  44]],
#
#        [[232, 187, 132],
#         [232, 187, 132],
#         [233, 188, 133],
#         ...,
#         [100,  54,  54],
#         [ 92,  48,  47],
#         [ 84,  42,  43]],
#
#        [[232, 187, 132],
#         [233, 188, 133],
#         [233, 188, 133],
#         ...,
#         [ 99,  53,  53],
#         [ 91,  47,  46],
#         [ 83,  41,  42]],
#
#        ...,
#
#        [[199, 119,  82],
#         [199, 119,  82],
#         [200, 120,  83],
#         ...,
#         [189,  99,  65],
#         [187,  97,  63],
#         [187,  97,  63]],
#
#        [[199, 119,  82],
#         [199, 119,  82],
#         [199, 119,  82],
#         ...,
#         [188,  98,  64],
#         [186,  96,  62],
#         [188,  95,  62]],
#
#        [[199, 119,  82],
#         [199, 119,  82],
#         [199, 119,  82],
#         ...,
#         [188,  98,  64],
#         [188,  95,  62],
#         [188,  95,  62]]], dtype=uint8)

# %%
misc.imshow('./cat.jpg')
# Out:
# D:\anacondna\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imshow` is deprecated!
# `imshow` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``matplotlib.pyplot.imshow`` instead.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-7d2182dddf70> in <module>
# ----> 1 misc.imshow('./cat.jpg')
#
# D:\anacondna\lib\site-packages\numpy\lib\utils.py in newfunc(*args, **kwds)
#      99             """`arrayrange` is deprecated, use `arange` instead!"""
#     100             warnings.warn(depdoc, DeprecationWarning, stacklevel=2)
# --> 101             return func(*args, **kwds)
#     102
#     103         newfunc = _set_function_name(newfunc, old_name)
#
# D:\anacondna\lib\site-packages\scipy\misc\pilutil.py in imshow(arr)
#     490
#     491     """
# --> 492     im = toimage(arr)
#     493     fnum, fname = tempfile.mkstemp('.png')
#     494     try:
#
# D:\anacondna\lib\site-packages\numpy\lib\utils.py in newfunc(*args, **kwds)
#      99             """`arrayrange` is deprecated, use `arange` instead!"""
#     100             warnings.warn(depdoc, DeprecationWarning, stacklevel=2)
# --> 101             return func(*args, **kwds)
#     102
#     103         newfunc = _set_function_name(newfunc, old_name)
#
# D:\anacondna\lib\site-packages\scipy\misc\pilutil.py in toimage(arr, high, low, cmin, cmax, pal, mode, channel_axis)
#     325                                 ((3 in shape) or (4 in shape)))
#     326     if not valid:
# --> 327         raise ValueError("'arr' does not have a suitable array shape for "
#     328                          "any mode.")
#     329     if len(shape) == 2:
#
# ValueError: 'arr' does not have a suitable array shape for any mode.

# %%
plt.imshow(cat)

# %%
cat2 = misc.imrotate(cat,60)
plt.imshow(cat2)
# Out:
# D:\anacondna\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imrotate` is deprecated!
# `imrotate` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.rotate`` instead.
#   """Entry point for launching an IPython kernel.

# %%
cat3 = misc.imresize(cat,10)
plt.imshow(cat3)
# Out:
# D:\anacondna\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   """Entry point for launching an IPython kernel.

# %%
# 滤波操作
'''    ftype : str
        The filter that has to be applied. Legal values are:
        'blur', 'contour', 'detail', 'edge_enhance', 'edge_enhance_more',
        'emboss', 'find_edges', 'smooth', 'smooth_more', 'sharpen'.'''
cat4 = misc.imfilter(cat,'emboss')
plt.imshow(cat4)
# Out:
# D:\anacondna\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: `imfilter` is deprecated!
# `imfilter` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use Pillow filtering functionality directly.
#   """Entry point for launching an IPython kernel.

# %%
# scipy自带的一张图片，练习
# 使用任何图片都可以
face = misc.face()
plt.imshow(face)

# %%
from scipy import ndimage

# %%
# 0 纯黑，255纯白
face2 = ndimage.shift(face,shift = [0,-500,0],cval = 255)
plt.imshow(face2)

# %%
'''mode : {'reflect', 'constant', 'nearest', 'mirror', 'wrap'}, optional
    The `mode` parameter determines how the input array is extended
    when the filter overlaps a border. Default is 'reflect'. Behavior
    for each valid value is as follows:

    'reflect' (`d c b a | a b c d | d c b a`)
        The input is extended by reflecting about the edge of the last
        pixel.

    'constant' (`k k k k | a b c d | k k k k`)
        The input is extended by filling all values beyond the edge with
        the same constant value, defined by the `cval` parameter.

    'nearest' (`a a a a | a b c d | d d d d`)
        The input is extended by replicating the last pixel.

    'mirror' (`d c b | a b c d | c b a`)
        The input is extended by reflecting about the center of the last
        pixel.

    'wrap' (`a b c d | a b c d | a b c d`)
        The input is extended by wrapping around to the opposite edge.'''
face2 = ndimage.shift(face,shift = [0,-500,3],mode = 'mirror')
plt.imshow(face2)

# %%
from scipy import matrix

# %%
A = matrix(np.random.randint(0,10,size=(4,5)))
A
# Out:
# matrix([[1, 5, 9, 0, 4],
#         [1, 6, 0, 1, 7],
#         [4, 2, 6, 3, 8],
#         [6, 0, 1, 0, 0]])

# %%
B = matrix(np.random.randint(0,10,size=(5,4)))
B
# Out:
# matrix([[8, 5, 7, 9],
#         [8, 5, 7, 7],
#         [5, 1, 8, 2],
#         [4, 2, 7, 8],
#         [4, 1, 2, 3]])

# %%
S = np.random.randint(0,100,size = (10000,10000))
S
# Out:
# array([[81,  4, 86, ..., 35, 82, 58],
#        [52, 52, 91, ..., 37, 66, 20],
#        [67, 21, 46, ..., 14, 30,  0],
#        ...,
#        [85, 74, 92, ..., 49,  3, 20],
#        [89, 66, 57, ..., 10,  5, 48],
#        [85, 73, 14, ..., 24, 51, 90]])

# %%
np.save('./S.npy',S)

# %%
S[S<98] = 0

# %%
S
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
np.save('./S2.npy',S)

# %%
from scipy import sparse

# %%
S1 = sparse.csc_matrix(S)
S1
# Out:
# <10000x10000 sparse matrix of type '<class 'numpy.int32'>'
# 	with 1997461 stored elements in Compressed Sparse Column format>

# %%
print(S1)
# Out:
#   (28, 0)	98
#   (94, 0)	98
#   (97, 0)	98
#   (149, 0)	99
#   (369, 0)	99
#   (420, 0)	98
#   (433, 0)	99
#   (441, 0)	99
#   (471, 0)	98
#   (595, 0)	98
#   (612, 0)	98
#   (618, 0)	99
#   (706, 0)	99
#   (747, 0)	98
#   (764, 0)	98
#   (809, 0)	99
#   (829, 0)	98
#   (891, 0)	99
#   (941, 0)	99
#   (1018, 0)	98
#   (1095, 0)	99
#   (1100, 0)	99
#   (1118, 0)	98
#   (1144, 0)	98
#   (1192, 0)	99
#   :	:
#   (8595, 9999)	99
#   (8668, 9999)	99
#   (8869, 9999)	98
#   (8911, 9999)	99
#   (8959, 9999)	99
#   (9017, 9999)	98
#   (9094, 9999)	99
#   (9180, 9999)	98
#   (9224, 9999)	99
#   (9235, 9999)	99
#   (9236, 9999)	99
#   (9244, 9999)	99
#   (9264, 9999)	99
#   (9277, 9999)	98
#   (9384, 9999)	98
#   (9456, 9999)	98
#   (9581, 9999)	98
#   (9654, 9999)	98
#   (9672, 9999)	98
#   (9681, 9999)	99
#   (9737, 9999)	99
#   (9782, 9999)	99
#   (9937, 9999)	99
#   (9967, 9999)	99
#   (9995, 9999)	99

# %%
sparse.save_npz('./sparse.npz',S1)

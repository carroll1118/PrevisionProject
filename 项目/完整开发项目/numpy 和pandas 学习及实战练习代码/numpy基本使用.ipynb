# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib  inline

# %%
img = plt.imread('./a.jpg')

# %%
img.shape
# Out:
# (263, 351, 3)

# %%
plt.imshow(img)

# %%
head = img[50:180,100:250]
plt.imshow(head)

# %%
head.shape
# Out:
# (130, 150, 3)

# %%
img = img[50:180:5,100:250:5]
plt.imshow(img)
